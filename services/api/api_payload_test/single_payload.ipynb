# %%
import requests

url = "http://localhost:8000/predict"

# Build the payload (matches RealTimePredictionRequest schema)
payload = {
    "Time": 472.0,
    "V1": -3.043541,
    "V2": -3.157307,
    "V3": 1.088463,
    "V4": 2.288644,
    "V5": 1.359805,
    "V6": 1.064823,
    "V7": 0.325574,
    "V8": -0.067794,
    "V9": -0.270953,
    "V10": -0.838587,
    "V11": -0.414575,
    "V12": -0.503141,
    "V13": 0.676502,
    "V14": -1.692029,
    "V15": 2.000635,
    "V16": 0.666780,
    "V17": 0.867832,
    "V18": 1.725321,
    "V19": 0.283345,
    "V20": 2.102339,
    "V21": 0.661696,
    "V22": 0.435477,
    "V23": 1.375966,
    "V24": -0.293803,
    "V25": 0.279798,
    "V26": -0.145362,
    "V27": -0.252773,
    "V28": 0.035764,
    "Amount": 529.0
}

response = requests.post(url, json=payload)

if response.status_code == 200:
    result = response.json()
    print(f"Prediction: {result['prediction']}")
    print(f"Probability: {result['probability']}")
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# Prediction: 1
# Probability: 0.9946733117103577

# %%
event = {"transaction_id": "9659c0b5-4623-40bf-88b2-de14429e2fcd",
 "features": [-3.043541, -3.157307, 1.088463, 2.288644, 1.359805, -1.064823, 0.325574, -0.067794, -0.270953, -0.838587, -0.414575, -0.503141, 0.676502, -1.692029, 2.000635, 0.66678, 0.599717, 1.725321, 0.283345, 2.102339, 0.661696, 0.435477, 1.375966, -0.293803, 0.279798, -0.145362, -0.252773, 0.035764, 529.0], 
 "prediction": 1}

# %%
payload = {}
for x, y in event.items():
    if x == "features":
        j=0
        for i in y:
            payload[f"V{j}"] = i
            j+=1
    elif x == "prediction":
        payload["prediction"] = i

payload["transaction_id"] = event["transaction_id"]

# %%
payload
# Out:
# {'V0': -3.043541,
#  'V1': -3.157307,
#  'V2': 1.088463,
#  'V3': 2.288644,
#  'V4': 1.359805,
#  'V5': -1.064823,
#  'V6': 0.325574,
#  'V7': -0.067794,
#  'V8': -0.270953,
#  'V9': -0.838587,
#  'V10': -0.414575,
#  'V11': -0.503141,
#  'V12': 0.676502,
#  'V13': -1.692029,
#  'V14': 2.000635,
#  'V15': 0.66678,
#  'V16': 0.599717,
#  'V17': 1.725321,
#  'V18': 0.283345,
#  'V19': 2.102339,
#  'V20': 0.661696,
#  'V21': 0.435477,
#  'V22': 1.375966,
#  'V23': -0.293803,
#  'V24': 0.279798,
#  'V25': -0.145362,
#  'V26': -0.252773,
#  'V27': 0.035764,
#  'V28': 529.0,
#  'prediction': 529.0,
#  'transaction_id': '9659c0b5-4623-40bf-88b2-de14429e2fcd'}
