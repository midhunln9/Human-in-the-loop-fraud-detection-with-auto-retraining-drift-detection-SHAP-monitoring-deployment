# %%
import pandas as pd
from sqlalchemy import create_engine, text

DB_HOST = "database-1.cf2eqwkcalek.ap-south-1.rds.amazonaws.com"
DB_PORT = 5432
DB_NAME = "postgres"
DB_USER = "postgres"
DB_PASSWORD = "postgres1999"

DATABASE_URL = f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

engine = create_engine(DATABASE_URL, pool_pre_ping=True)

query = text("SELECT * FROM transactions LIMIT 100;")

with engine.connect() as conn:
    df = pd.read_sql(query, conn)

df
# Out:
#                          transaction_id        V0        V1        V2  \
# 0  c5f20c78-9928-4b32-b0b1-a2895daf2ec7  0.000000  0.000000  0.000000
# 1  0c979c2f-0bae-4b9c-b81e-868be1f57a71  0.000000  0.000000  0.000000
# 2  e3c37a01-5141-43e8-a873-e378d1120462  0.000000  0.000000  0.000000
# 3  b565a7c6-aa5c-4fbc-88be-99580fb69a42  0.000000  0.000000  0.000000
# 4  eec4b313-87b2-495f-9333-22033658e5bd  0.000000  0.000000  0.000000
# 5  3cab4530-2498-4390-bb0b-45c56b0b34fb -3.043541 -3.157307  1.088463
#
#          V3        V4        V5        V6        V7        V8  ...       V20  \
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  ...  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  ...  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  ...  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  ...  0.000000
# 4  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  ...  0.000000
# 5  2.288644  1.359805 -1.064823  0.325574 -0.067794 -0.270953  ...  0.661696
#
#         V21       V22       V23       V24       V25       V26       V27  \
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5  0.435477  1.375966 -0.293803  0.279798 -0.145362 -0.252773  0.035764
#
#      V28  prediction
# 0    0.0           0
# 1    0.0           0
# 2    0.0           0
# 3    0.0           0
# 4    0.0           0
# 5  529.0           1
#
# [6 rows x 31 columns]
